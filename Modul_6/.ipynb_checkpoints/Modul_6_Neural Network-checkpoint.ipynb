# %% [markdown]
# # Neural Network
# - Pengantar Neural Networks
# - Pengertian Hidden Layer
# - Pengertian Neuron
# - Pengertian Learning Rate
# - Fungsi Aktivasi
# - Forward & Backpropagation

# %% [markdown]
# ## Learning Rate

# %% [markdown]
# ## Fungsi Aktivasi

# %% [markdown]
# Activation Function is an equation that is used to convert an input of a node in a layer to an output. It is a logic “gate” in between the input feeding the current neuron and its output going to the next layer.

# %% [markdown]
# ![activation_function.png](attachment:activation_function.png)

# %% [markdown]
# ### Contoh

# %% [markdown]
# <b>Sigmoid</b>

# %% [markdown]
# <b>Rectified Linear Unit (ReLU)</b>

# %% [markdown]
# <b>Softmax</b>

# %% [markdown]
# ## Propagation
